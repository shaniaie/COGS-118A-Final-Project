# %%
import pandas as pd
import re

# %%
colnames = ['letter', 'x-box','y-box', 'width', 'height', 'pixels', 'x-bar', 'y-bar', 'x2bar', 'y2bar', 'xybar', 'x2ybr', 'xy2br', 'x-ege', 'xegvy', 'y-ege', 'yegvx']
df = pd.read_csv('letter-recognition.csv', names= colnames)
p = re.compile('[A-M]')
df['letter'] = df['letter'].apply(lambda x: 1 if p.match(x) else -1)
df
# Out:
#        letter  x-box  y-box  width  height  pixels  x-bar  y-bar  x2bar  \
# 0          -1      2      8      3       5       1      8     13      0
# 1           1      5     12      3       7       2     10      5      5
# 2           1      4     11      6       8       6     10      6      2
# 3          -1      7     11      6       6       3      5      9      4
# 4           1      2      1      3       1       1      8      6      6
# ...       ...    ...    ...    ...     ...     ...    ...    ...    ...
# 19995       1      2      2      3       3       2      7      7      7
# 19996       1      7     10      8       8       4      4      8      6
# 19997      -1      6      9      6       7       5      6     11      3
# 19998      -1      2      3      4       2       1      8      7      2
# 19999       1      4      9      6       6       2      9      5      3
#
#        y2bar  xybar  x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 0          6      6     10      8      0      8      0      8
# 1          4     13      3      9      2      8      4     10
# 2          6     10      3      7      3      7      3      9
# 3          6      4      4     10      6     10      2      8
# 4          6      6      5      9      1      7      5     10
# ...      ...    ...    ...    ...    ...    ...    ...    ...
# 19995      6      6      6      4      2      8      3      7
# 19996      9     12      9     13      2      9      3      7
# 19997      7     11      9      5      2     12      2      4
# 19998      6     10      6      8      1      9      5      8
# 19999      1      8      1      8      2      7      2      8
#
# [20000 rows x 17 columns]
